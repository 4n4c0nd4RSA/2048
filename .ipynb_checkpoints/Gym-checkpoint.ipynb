# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras import layers, models, optimizers

tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# Out:
# WARNING:tensorflow:From C:\Users\Heinrich\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Heinrich\AppData\Local\Temp\ipykernel_17648\928032085.py:6: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %% [markdown]
# # Creating the Model

# %%
def create_model():
    model = models.Sequential([
        layers.Conv2D(128, kernel_size=(2, 2), activation='relu', input_shape=(4, 4, 1), padding='same'),
        layers.Conv2D(128, kernel_size=(2, 2), activation='relu', padding='same'),
        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.Dense(4, activation='linear')
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mse')
    return model

# %% [markdown]
# # Or Load the Model

# %%
model = load_model('dev_model.keras') # create_model() #

# %% [markdown]
# # Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         640
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 128)         65664
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 256)               524544
#
#  dense_3 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 591876 (2.26 MB)
# Trainable params: 591876 (2.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Define The Game

# %%
import numpy as np
import random

# Constants
BACKGROUND_COLOR = (187, 173, 160)
TEXT_COLOR = (119, 110, 101)
TILE_COLORS = {
    2: (238, 228, 218),
    4: (237, 224, 200),
    8: (242, 177, 121),
    16: (245, 149, 99),
    32: (246, 124, 95),
    64: (246, 94, 59),
    128: (237, 207, 114),
    256: (237, 204, 97),
    512: (237, 200, 80),
    1024: (237, 197, 63),
    2048: (237, 194, 46),
}
EMPTY_COLOR = (205, 192, 180)
TILE_SIZE = 75
TILE_MARGIN = 15
FONT_SIZE = 36

def init_grid():
    return np.zeros((4, 4), dtype=int)

def add_tile(grid):
    empty_cells = [(i, j) for i in range(4) for j in range(4) if grid[i][j] == 0]
    if empty_cells:
        i, j = random.choice(empty_cells)
        grid[i][j] = 2 if random.random() < 0.9 else 4
    return grid

def compress(grid):
    new_grid = np.zeros((4, 4), dtype=int)
    done = False
    for i in range(4):
        count = 0
        for j in range(4):
            if grid[i][j] != 0:
                new_grid[i][count] = grid[i][j]
                if j != count:
                    done = True
                count += 1
    return new_grid, done

def merge(grid):
    done = False
    reward_delta = 0
    for i in range(4):
        for j in range(3):
            if grid[i][j] == grid[i][j + 1] and grid[i][j] != 0:
                reward_delta = 5
                grid[i][j] *= 2
                grid[i][j + 1] = 0
                done = True
    return grid, done, reward_delta

def reverse(grid):
    return np.fliplr(grid)

def transpose(grid):
    return np.transpose(grid)

def calculate_reward(old_grid, new_grid, action):
        """
        Calculate the reward given the old and new grid states after a specific action.
        """
        if np.array_equal(old_grid, new_grid):
            # No change in the grid, penalize the agent
            return -5  # This penalty is severe to make the agent avoid futile actions
    
        # Calculate merged value
        new_unique = np.unique(new_grid)
        old_unique = np.unique(old_grid)
        merged_sum = sum([value for value in new_unique if value not in old_unique and value > 2])
    
        # Reward for creating new tiles by merging
        reward = merged_sum * 0.1  # Scale the merged score to fine-tune
    
        # Additional rewards/penalties
        empty_cells_new = len(new_grid[new_grid == 0])
        empty_cells_old = len(old_grid[old_grid == 0])
    
        if empty_cells_new > empty_cells_old:
            # Reward for increasing empty cells (good move)
            reward += (empty_cells_new - empty_cells_old) * 1.5
        elif empty_cells_new < empty_cells_old:
            # Penalize for reducing empty space unnecessarily
            reward -= (empty_cells_old - empty_cells_new) * 1.5
        return reward

def simulate_move(grid, direction):
    """ Simulate a move without altering the original grid and calculate the reward. """
    temp_grid = grid.copy()
    if direction == 'LEFT':
        temp_grid, done = compress(temp_grid)
        temp_grid, temp, reward_delta = merge(temp_grid)
        temp_grid, _ = compress(temp_grid)
    elif direction == 'RIGHT':
        temp_grid = reverse(temp_grid)
        temp_grid, done = compress(temp_grid)
        temp_grid, temp, reward_delta = merge(temp_grid)
        temp_grid, _ = compress(temp_grid)
        temp_grid = reverse(temp_grid)
    elif direction == 'UP':
        temp_grid = transpose(temp_grid)
        temp_grid, done = compress(temp_grid)
        temp_grid, temp, reward_delta = merge(temp_grid)
        temp_grid, _ = compress(temp_grid)
        temp_grid = transpose(temp_grid)
    elif direction == 'DOWN':
        temp_grid = transpose(temp_grid)
        temp_grid = reverse(temp_grid)
        temp_grid, done = compress(temp_grid)
        temp_grid, temp, reward_delta = merge(temp_grid)
        temp_grid, _ = compress(temp_grid)
        temp_grid = reverse(temp_grid)
        temp_grid = transpose(temp_grid)
    
    reward = calculate_reward(grid, temp_grid, direction) + reward_delta
    return reward

def rank_rewards(grid, selected_direction):
    directions = ['LEFT', 'RIGHT', 'UP', 'DOWN']
    rewards = {dir: simulate_move(grid, dir) for dir in directions}
    sorted_rewards = sorted(rewards.items(), key=lambda x: x[1], reverse=True)
    rank = 1 + [dir for dir, reward in sorted_rewards].index(selected_direction)
    rank_reward_deltas = {1: 5, 2: 2, 3: 1, 4: 0}
    return rank_reward_deltas[rank]

def move(grid, direction, score, steps):
    original_grid = grid.copy()  # Copy to check for changes
    reward_delta = simulate_move(grid, direction) 

    if direction == 'LEFT':
        grid, done = compress(grid)
        grid, temp, reward_delta = merge(grid)
        done = done or temp
        grid, _ = compress(grid)
    elif direction == 'RIGHT':
        grid = reverse(grid)
        grid, done = compress(grid)
        grid, temp, reward_delta = merge(grid)
        done = done or temp
        grid, _ = compress(grid)
        grid = reverse(grid)
    elif direction == 'UP':
        grid = transpose(grid)
        grid, done = compress(grid)
        grid, temp, reward_delta = merge(grid)
        done = done or temp
        grid, _ = compress(grid)
        grid = transpose(grid)
    elif direction == 'DOWN':
        grid = transpose(grid)
        grid = reverse(grid)
        grid, done = compress(grid)
        grid, temp, reward_delta = merge(grid)
        done = done or temp
        grid, _ = compress(grid)
        grid = reverse(grid)
        grid = transpose(grid)

    # Adjust the final reward based on ranking of the move
    rank_reward_delta = rank_rewards(original_grid, direction)
    
    if np.array_equal(original_grid, grid):
        done = True  # Prevent stuck states

    if done:
        score += np.sum(grid[grid >= 2] // 2)
    reward = calculate_reward(original_grid,grid,direction)
    reward += reward_delta
    reward += rank_reward_delta
    return grid, reward

# %%
grid = init_grid()
grid = add_tile(grid)
score = 0

# %%
import matplotlib.pyplot as plt
from matplotlib import colors

def display_grid(grid):
    """
    Display a 2048 game grid using matplotlib.
    """
    color_map = colors.ListedColormap(['#CDC1B4', '#EEE4DA', '#EDE0C8', '#F2B179', '#F59563', 
                                       '#F67C5F', '#F65E3B', '#EDCF72', '#EDCC61', '#EDC850', '#EDC53F', '#EDC22E'])
    # Create an array where each cell is a power of 2: 2**1, 2**2, ..., 2**11, 2**12
    labels = grid
    labels[labels == 1] = 0  # replace 1 with 0 for empty cells as 2**0 is 1
    
    # Create discrete boundaries for the color map from 0 to max+1
    bounds = [0]+[2**i for i in range(1, 13)]
    norm = colors.BoundaryNorm(bounds, color_map.N)
    
    fig, ax = plt.subplots()
    mat = ax.matshow(labels, cmap=color_map, norm=norm)
    
    # Adding the numbers on the tiles
    for i in range(4):
        for j in range(4):
            c = labels[i, j]
            if c > 0:
                ax.text(j, i, str(int(c)), va='center', ha='center', color='black' if c < 8 else 'white')
    
    # Title and other formatting
    plt.title('2048 Game Grid')
    plt.axis('off')  # turn off the axis
    plt.show()

# %% [markdown]
# # Training

# %%
high_score = 5000

# %%
import numpy as np
import random
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from collections import deque

# Hyperparameters
STATE_SHAPE = (4, 4, 1)  # Shape of the state
ACTION_SIZE = 4  # Number of possible actions (up, down, left, right)
REPLAY_MEMORY_SIZE = 1000000  # Number of tuples in experience replay
MIN_REPLAY_MEMORY_SIZE = 16  # Minimum number of tuples for training
MINIBATCH_SIZE = 16  # Size of minibatch used for training
DISCOUNT = 0.95  # Discount factor
UPDATE_TARGET_EVERY = 1500  # How frequently to update the target network
LEARNING_RATE = 0.0001
    
# Counter to update target model
target_update_counter = 0

action_map = {
    0: 'UP',
    1: 'DOWN',
    2: 'LEFT',
    3: 'RIGHT'
}

scores = []

# Get a minibatch of random samples from memory
def train_replay():
    if len(replay_memory) < MIN_REPLAY_MEMORY_SIZE:
        return

    minibatch = random.sample(replay_memory, MINIBATCH_SIZE)

    current_states = np.array([transition[0] for transition in minibatch])
    current_qs_list = model.predict(current_states, verbose=0)
    
    new_current_states = np.array([transition[3] for transition in minibatch])
    future_qs_list = target_model.predict(new_current_states, verbose=0)

    X = []
    y = []

    for index, (current_state, action, reward, new_current_state) in enumerate(minibatch):
        max_future_q = np.max(future_qs_list[index])
        new_q = reward + DISCOUNT * max_future_q

        current_qs = current_qs_list[index]
        current_qs[action] = new_q

        X.append(current_state)
        y.append(current_qs)

    model.fit(np.array(X), np.array(y), batch_size=MINIBATCH_SIZE, verbose=0, shuffle=True)

    global target_update_counter
    target_update_counter += 1
    if target_update_counter > UPDATE_TARGET_EVERY:
        print("TARGET UPDATED")
        target_model.set_weights(model.get_weights())
        target_update_counter = 0

def play_one_step(state, epsilon, score, model):
    original_state = np.copy(state)  # Preserve the original state for comparison

    # Decide on an action
    if np.random.random() > epsilon:
        state_tensor = tf.convert_to_tensor(state.reshape((1, 4, 4, 1)), dtype=tf.float32)
        action_probs = model(state_tensor, training=False)
        action = tf.argmax(action_probs[0]).numpy()
    else:
        action = np.random.randint(0, 4)  # Random action (explore)

    # Perform the action
    next_state, reward = move(state, action_map[action], score, steps)  # Assumes move() is adjusted to return the next state and reward
    done = True
    # If state is changed, add a random tile, else, apply a penalty
    if not np.array_equal(next_state, original_state):
        next_state = add_tile(next_state)
    else:
        reward = -5  # No change in state, apply a penalty for dormancy

    # Save the experience to replay memory
    add_to_replay_memory(original_state, action, reward, next_state)
    return next_state, reward

# Add transition to replay memory
def add_to_replay_memory(state, action, reward, next_state):
    replay_memory.append((state, action, reward, next_state))
        
model = load_model('dev_model.keras') # create_model() #

# Target Model
target_model = load_model('17_model.keras') # 

# Replay memory
replay_memory = deque(maxlen=REPLAY_MEMORY_SIZE)

# Example game loop
state = np.zeros((4, 4), dtype=int)  # Initialize your
state = add_tile(state)
done = False
score = 0
epsilon = 1.0  # Start with a high epsilon to promote exploration
epsilon_decay = 0.999  # Decay epsilon
min_epsilon = 0.01  # Minimum epsilon
steps = 0
dorment = 0
rewards = []

while not done:
    steps += 1
    new_state, reward = play_one_step(state, epsilon,score,model)
    score += reward
    if np.array_equal(state, new_state):
        dorment += 1
    state = new_state
    if dorment > 8:
        done = True
    epsilon = max(epsilon * epsilon_decay, min_epsilon)  # Decay epsilon
    if steps % 4 == 0:
        train_replay()
    if done:
        if score > high_score:
            high_score = score
            model.save('dev_model.keras')
            print(f'Score to beat: {high_score}')
            print(f'model saved, score: {high_score}')
        train_replay()
        display_grid(state)
        state = np.zeros((4, 4), dtype=int)  # Reset state to initial
        state = add_tile(state)
        scores.append(score)
        steps = 0
        print(f'Score to beat: {high_score}')
        done = False
        if high_score > 8000:
            done = True
    if dorment > 8:
        print(f'Dorment model score: {score}')
        score = 0
        dorment = 0
# Out:
# Score to beat: 5000
# Dorment model score: 251.60000000000002
# Score to beat: 5000
# Dorment model score: 400.79999999999995
# Score to beat: 5000
# Dorment model score: 407.09999999999997
# Score to beat: 5000
# Dorment model score: 767.9
# Score to beat: 5000
# Dorment model score: 725.5
# Score to beat: 5000
# Dorment model score: 923.9
# Score to beat: 5000
# Dorment model score: 1271.1
# Score to beat: 5000
# Dorment model score: 1068.8000000000002
# Score to beat: 5000
# Dorment model score: 905.5
# Score to beat: 5000
# Dorment model score: 1366.1999999999998
# Score to beat: 5000
# Dorment model score: 1172.8999999999996
# Score to beat: 5000
# Dorment model score: 1011.1999999999998
# Score to beat: 5000
# Dorment model score: 1770.4999999999998
# Score to beat: 5000
# Dorment model score: 1431.1000000000004
# Score to beat: 5000
# Dorment model score: 1448.6
# Score to beat: 5000
# Dorment model score: 2185.9
# Score to beat: 5000
# Dorment model score: 1728.4999999999995
# Score to beat: 5000
# Dorment model score: 945.8
# Score to beat: 5000
# Dorment model score: 906.5000000000001
# Score to beat: 5000
# Dorment model score: 1698.1000000000001
# Score to beat: 5000
# Dorment model score: 1361.9999999999998
# Score to beat: 5000
# Dorment model score: 954.7999999999998
# Score to beat: 5000
# Dorment model score: 1226.4999999999995
# Score to beat: 5000
# Dorment model score: 1289.3
# Score to beat: 5000
# Dorment model score: 1777.8
# Score to beat: 5000
# Dorment model score: 1495.6999999999998
# Score to beat: 5000
# Dorment model score: 2504.4999999999995
# Score to beat: 5000
# Dorment model score: 2107.2
# Score to beat: 5000
# Dorment model score: 1756.5999999999997
# Score to beat: 5000
# Dorment model score: 1511.0
# Score to beat: 5000
# Dorment model score: 1210.1000000000001
# Score to beat: 5000
# Dorment model score: 1947.6000000000004
# Score to beat: 5000
# Dorment model score: 1322.3000000000002
# Score to beat: 5000
# Dorment model score: 1191.5000000000002
# Score to beat: 5000
# Dorment model score: 1233.9999999999998
# Score to beat: 5000
# Dorment model score: 1037.2
# Score to beat: 5000
# Dorment model score: 2157.0000000000005
# TARGET UPDATED
# Score to beat: 5000
# Dorment model score: 1710.1
# Score to beat: 5000
# Dorment model score: 58.19999999999999
# Score to beat: 5000
# Dorment model score: 1774.8
# Score to beat: 5000
# Dorment model score: 1257.1
# Score to beat: 5000
# Dorment model score: 1134.2
# Score to beat: 5000
# Dorment model score: 1737.9999999999998
# Score to beat: 5000
# Dorment model score: 2148.0
# Score to beat: 5000
# Dorment model score: 864.3
# Score to beat: 5000
# Dorment model score: 1354.1999999999998
# Score to beat: 5000
# Dorment model score: 1667.5
# Score to beat: 5000
# Dorment model score: 222.89999999999998
# Score to beat: 5000
# Dorment model score: 1837.9999999999998
# Score to beat: 5000
# Dorment model score: 597.6999999999999
# Score to beat: 5000
# Dorment model score: 508.5
# Score to beat: 5000
# Dorment model score: 2196.2
# Score to beat: 5000
# Dorment model score: 1575.1999999999998
# Score to beat: 5000
# Dorment model score: 1084.9
# Score to beat: 5000
# Dorment model score: 1277.6000000000001
# Score to beat: 5000
# Dorment model score: 1405.2999999999997
# Score to beat: 5000
# Dorment model score: 1999.3
# Score to beat: 5000
# Dorment model score: 1174.2
# Score to beat: 5000
# Dorment model score: 1233.6999999999998
# Score to beat: 5000
# Dorment model score: 590.0
# Score to beat: 5000
# Dorment model score: 1476.3000000000002
# Score to beat: 5000
# Dorment model score: 1179.4
# Score to beat: 5000
# Dorment model score: 1451.9999999999998
# Score to beat: 5000
# Dorment model score: 1248.3
# Score to beat: 5000
# Dorment model score: 1761.1
# Score to beat: 5000
# Dorment model score: 1863.5999999999997
# Score to beat: 5000
# Dorment model score: 1560.2999999999997
# Score to beat: 5000
# Dorment model score: 1726.4999999999998
# Score to beat: 5000
# Dorment model score: 2343.7000000000003
# Score to beat: 5000
# Dorment model score: 1947.6
# Score to beat: 5000
# Dorment model score: 1194.7
# Score to beat: 5000
# Dorment model score: 2192.1
# Score to beat: 5000
# Dorment model score: 690.6999999999998
# TARGET UPDATED
# Score to beat: 5000
# Dorment model score: 1840.0
# Score to beat: 5000
# Dorment model score: 1491.6999999999998
# Score to beat: 5000
# Dorment model score: 935.2
# Score to beat: 5000
# Dorment model score: 876.9999999999999
# Score to beat: 5000
# Dorment model score: 2200.2
# Score to beat: 5000
# Dorment model score: 1723.1000000000001
# Score to beat: 5000
# Dorment model score: 717.4
# Score to beat: 5000
# Dorment model score: 1181.9999999999998
# Score to beat: 5000
# Dorment model score: 977.1999999999999
# Score to beat: 5000
# Dorment model score: 1686.7999999999997
# Score to beat: 5000
# Dorment model score: 360.3
# Score to beat: 5000
# Dorment model score: 441.8
# Score to beat: 5000
# Dorment model score: 2394.2999999999997
# Score to beat: 5000
# Dorment model score: 1153.7
# Score to beat: 5000
# Dorment model score: 1861.6
# Score to beat: 5000
# Dorment model score: 676.5
# Score to beat: 5000
# Dorment model score: 1965.3999999999999
# Score to beat: 5000
# Dorment model score: 2190.7
# Score to beat: 5000
# Dorment model score: 1362.0
# Score to beat: 5000
# Dorment model score: 2127.5000000000005
# Score to beat: 5000
# Dorment model score: 3223.5
# Score to beat: 5000
# Dorment model score: 1519.7999999999997
# Score to beat: 5000
# Dorment model score: 2050.3999999999996
# Score to beat: 5000
# Dorment model score: 1387.2
# Score to beat: 5000
# Dorment model score: 850.9
# Score to beat: 5000
# Dorment model score: 1135.7
# Score to beat: 5000
# Dorment model score: 2027.9999999999995
# Score to beat: 5000
# Dorment model score: 1278.2
# Score to beat: 5000
# Dorment model score: 328.6
# Score to beat: 5000
# Dorment model score: 668.1999999999999
# Score to beat: 5000
# Dorment model score: 1185.2
# Score to beat: 5000
# Dorment model score: 1319.6999999999996
# Score to beat: 5000
# Dorment model score: 1224.8999999999999
# Score to beat: 5000
# Dorment model score: 2138.3999999999996
# Score to beat: 5000
# Dorment model score: 2119.7
# TARGET UPDATED
# Score to beat: 5000
# Dorment model score: 2856.8
# Score to beat: 5000
# Dorment model score: 1845.6000000000001
# Score to beat: 5000
# Dorment model score: 1181.0
# Score to beat: 5000
# Dorment model score: 688.6999999999999
# Score to beat: 5000
# Dorment model score: 1864.4
# Score to beat: 5000
# Dorment model score: 99.0
# Score to beat: 5000
# Dorment model score: 1662.6
# Score to beat: 5000
# Dorment model score: 284.4
# Score to beat: 5000
# Dorment model score: 1290.6
# Score to beat: 5000
# Dorment model score: 1113.5
# Score to beat: 5000
# Dorment model score: 1123.1
# Score to beat: 5000
# Dorment model score: 2616.5
# Score to beat: 5000
# Dorment model score: 1578.0
# Score to beat: 5000
# Dorment model score: 1226.8
# Score to beat: 5000
# Dorment model score: 1302.8999999999999
# Score to beat: 5000
# Dorment model score: 523.9999999999999
# Score to beat: 5000
# Dorment model score: 743.1
# Score to beat: 5000
# Dorment model score: 1908.3
# Score to beat: 5000
# Dorment model score: 1447.2999999999997
# Score to beat: 5000
# Dorment model score: 70.1
# Score to beat: 5000
# Dorment model score: 952.7
# Score to beat: 5000
# Dorment model score: 927.6999999999998
# Score to beat: 5000
# Dorment model score: 498.0
# Score to beat: 5000
# Dorment model score: 1331.1
# Score to beat: 5000
# Dorment model score: 1859.4
# Score to beat: 5000
# Dorment model score: 509.1
# Score to beat: 5000
# Dorment model score: 1082.8
# Score to beat: 5000
# Dorment model score: 1511.1
# Score to beat: 5000
# Dorment model score: 645.2
# Score to beat: 5000
# Dorment model score: 1543.4999999999995
# Score to beat: 5000
# Dorment model score: 1170.6999999999998
# Score to beat: 5000
# Dorment model score: 1125.1999999999998
# Score to beat: 5000
# Dorment model score: 594.0999999999999
# Score to beat: 5000
# Dorment model score: 1244.8
# Score to beat: 5000
# Dorment model score: 3001.900000000001
# Score to beat: 5000
# Dorment model score: 1858.5999999999997
# Score to beat: 5000
# Dorment model score: 1545.6999999999998
# Score to beat: 5000
# Dorment model score: 2353.6000000000004
# TARGET UPDATED
# Score to beat: 5000
# Dorment model score: 4334.6
# Score to beat: 5000
# Dorment model score: 1862.4999999999998
# Score to beat: 5000
# Dorment model score: 4793.100000000001
# Score to beat: 5000
# Dorment model score: 2026.2000000000003
# Score to beat: 5000
# Dorment model score: 3690.8000000000015
# Score to beat: 5000
# Dorment model score: 1161.8999999999996
# Score to beat: 5000
# Dorment model score: 1439.5
# Score to beat: 5000
# Dorment model score: 2244.7
# Score to beat: 5000
# Dorment model score: 2131.3
# Score to beat: 5000
# Dorment model score: 1355.1
# Score to beat: 5000
# Dorment model score: 1367.3999999999996
# Score to beat: 5000
# Dorment model score: 2338.3
# Score to beat: 5000
# Dorment model score: 607.7
# Score to beat: 5000
# Dorment model score: 1714.0
# Score to beat: 5000
# Dorment model score: 2332.4000000000005
# Score to beat: 5000
# Dorment model score: 1654.8000000000002
# Score to beat: 5000
# Dorment model score: 1983.2000000000003
# Score to beat: 5000
# Dorment model score: 1319.7
# Score to beat: 5000
# Dorment model score: 1294.5
# Score to beat: 5000
# Dorment model score: 1367.9999999999998
# Score to beat: 5000
# Dorment model score: 1441.8999999999996
# Score to beat: 5000
# Dorment model score: 2539.7000000000007
# Score to beat: 5000
# Dorment model score: 933.1999999999999
# Score to beat: 5000
# Dorment model score: 1178.1
# Score to beat: 5000
# Dorment model score: 2232.6
# Score to beat: 5000
# Dorment model score: 882.5999999999999
# Score to beat: 5000
# Dorment model score: 1512.1
# Score to beat: 5000
# Dorment model score: 2493.9
# Score to beat: 5000
# Dorment model score: 518.1
# TARGET UPDATED
# Score to beat: 5000
# Dorment model score: 2000.6
# Score to beat: 5000
# Dorment model score: 1291.9999999999998
# Score to beat: 5000
# Dorment model score: 1293.0
# Score to beat: 5000
# Dorment model score: 1481.0999999999997
# Score to beat: 5000
# Dorment model score: 1975.4999999999998
# Score to beat: 5000
# Dorment model score: 1947.0
# Score to beat: 5000
# Dorment model score: 1403.6
# Score to beat: 5000
# Dorment model score: 1383.9
# Score to beat: 5000
# Dorment model score: 1869.4999999999998
# Score to beat: 5000
# Dorment model score: 1649.7999999999997
# Score to beat: 5000
# Dorment model score: 961.4999999999999
# Score to beat: 5000
# Dorment model score: 814.1999999999998
# Score to beat: 5000
# Dorment model score: 975.1999999999998
# Score to beat: 5000
# Dorment model score: 581.2
# Score to beat: 5000
# Dorment model score: 1396.8999999999999
# Score to beat: 5000
# Dorment model score: 2084.5999999999995
# Score to beat: 5000
# Dorment model score: 421.5
# Score to beat: 5000
# Dorment model score: 2276.4
# Score to beat: 5000
# Dorment model score: 1674.0
# Score to beat: 5000
# Dorment model score: 1529.7
# Score to beat: 5000
# Dorment model score: 2292.8
# Score to beat: 5000
# Dorment model score: 388.4
# Score to beat: 5000
# Dorment model score: 1222.9999999999998
# Score to beat: 5000
# Dorment model score: 1709.8999999999999
# Score to beat: 5000
# Dorment model score: 671.6
# Score to beat: 5000
# Dorment model score: 1400.5000000000002
# Score to beat: 5000
# Dorment model score: 1321.1999999999998
# Score to beat: 5000
# Dorment model score: 2208.4999999999995
# ----------------------------------------------------------------------
# KeyboardInterrupt                    Traceback (most recent call last)
# Cell In[9], line 130
#     128     print(f'Score to beat: {high_score}')
#     129     print(f'model saved, score: {high_score}')
# --> 130 train_replay()
#     131 display_grid(state)
#     132 state = np.zeros((4, 4), dtype=int)  # Reset state to initial
#
# Cell In[9], line 55, in train_replay()
#      52     X.append(current_state)
#      53     y.append(current_qs)
# ---> 55 model.fit(np.array(X), np.array(y), batch_size=MINIBATCH_SIZE, verbose=0, shuffle=True)
#      57 global target_update_counter
#      58 target_update_counter += 1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\engine\training.py:1745, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1735     self._cluster_coordinator = (
#    1736         tf.distribute.experimental.coordinator.ClusterCoordinator(
#    1737             self.distribute_strategy
#    1738         )
#    1739     )
#    1741 with self.distribute_strategy.scope(), training_utils.RespectCompiledTrainableState(  # noqa: E501
#    1742     self
#    1743 ):
#    1744     # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1745     data_handler = data_adapter.get_data_handler(
#    1746         x=x,
#    1747         y=y,
#    1748         sample_weight=sample_weight,
#    1749         batch_size=batch_size,
#    1750         steps_per_epoch=steps_per_epoch,
#    1751         initial_epoch=initial_epoch,
#    1752         epochs=epochs,
#    1753         shuffle=shuffle,
#    1754         class_weight=class_weight,
#    1755         max_queue_size=max_queue_size,
#    1756         workers=workers,
#    1757         use_multiprocessing=use_multiprocessing,
#    1758         model=self,
#    1759         steps_per_execution=self._steps_per_execution,
#    1760     )
#    1762     # Container that configures and calls `tf.keras.Callback`s.
#    1763     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\engine\data_adapter.py:1688, in get_data_handler(*args, **kwargs)
#    1686         return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1687     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1688 return DataHandler(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\engine\data_adapter.py:1292, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1289     self._steps_per_execution = steps_per_execution
#    1291 adapter_cls = select_data_adapter(x, y)
# -> 1292 self._adapter = adapter_cls(
#    1293     x,
#    1294     y,
#    1295     batch_size=batch_size,
#    1296     steps=steps_per_epoch,
#    1297     epochs=epochs - initial_epoch,
#    1298     sample_weights=sample_weight,
#    1299     shuffle=shuffle,
#    1300     max_queue_size=max_queue_size,
#    1301     workers=workers,
#    1302     use_multiprocessing=use_multiprocessing,
#    1303     distribution_strategy=tf.distribute.get_strategy(),
#    1304     model=model,
#    1305     pss_evaluation_shards=pss_evaluation_shards,
#    1306 )
#    1308 strategy = tf.distribute.get_strategy()
#    1310 self._current_step = 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\engine\data_adapter.py:355, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     351     return flat_dataset
#     353 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
# --> 355 dataset = self.slice_inputs(indices_dataset, inputs)
#     357 if shuffle == "batch":
#     359     def shuffle_batch(*batch):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\src\engine\data_adapter.py:407, in TensorLikeDataAdapter.slice_inputs(self, indices_dataset, inputs)
#     402 if self._shuffle:
#     403     # See b/141490660 for more details.
#     404     options.experimental_external_state_policy = (
#     405         tf.data.experimental.ExternalStatePolicy.IGNORE
#     406     )
# --> 407 dataset = dataset.with_options(options)
#     408 return dataset
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\tensorflow\python\data\ops\dataset_ops.py:2986, in DatasetV2.with_options(self, options, name)
#    2960 def with_options(self, options, name=None) -> "DatasetV2":
#    2961   """Returns a new `tf.data.Dataset` with the given options set.
#    2962
#    2963   The options are "global" in the sense they apply to the entire dataset.
#    (...)
#    2984     ValueError: when an option is set more than once to a non-default value
#    2985   """
# -> 2986   return _OptionsDataset(self, options, name=name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\tensorflow\python\data\ops\dataset_ops.py:4852, in _OptionsDataset.__init__(self, input_dataset, options, name)
#    4850 self._name = name
#    4851 with ops.colocate_with(input_dataset._variant_tensor):
# -> 4852   variant_tensor = gen_dataset_ops.options_dataset(
#    4853       input_dataset._variant_tensor, options_pb.SerializeToString(),
#    4854       **self._common_args)
#    4855 super(_OptionsDataset, self).__init__(input_dataset, variant_tensor)
#    4857 if self._options_attr:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\tensorflow\python\ops\gen_dataset_ops.py:4595, in options_dataset(input_dataset, serialized_options, output_types, output_shapes, metadata, name)
#    4593 if tld.is_eager:
#    4594   try:
# -> 4595     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    4596       _ctx, "OptionsDataset", name, input_dataset, "serialized_options",
#    4597       serialized_options, "output_types", output_types, "output_shapes",
#    4598       output_shapes, "metadata", metadata)
#    4599     return _result
#    4600   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# Data: a list of integers
data = scores
# Creating a plot
plt.figure(figsize=(10, 5))  # Optional: you can specify the size of the figure
plt.plot(data, marker='o')  # 'o' creates round markers at each data point

# Adding title and labels
plt.title('Score per game')
plt.xlabel('Game Number')
plt.ylabel('Score')

# Showing grid
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# # Make a Move

# %%
predictions = model.predict(grid.reshape(1, 4, 4, 1))

action = np.argmax(predictions[0])

print(f'Predictions: {predictions}')
print(f'Action: {action_map[action]}')

new_grid, reward = move(grid, action_map[action], score, steps)
if not np.array_equal(new_grid, grid):
    new_grid = add_tile(new_grid)
grid = new_grid
display_grid(grid)
print(f'Score: {score}')

# %%
print(grid)

# %% [markdown]
# # Save the Model

# %%
# model.save('dev_model.keras')

# %% [markdown]
# # Restart Game

# %%
loops += 1
grid = np.zeros((4, 4), dtype=int)  # Reset state to initial
grid = add_tile(grid)
print(f"End of game {loops}. Score: {score}")
scores.append(score)
score = 0
steps = 0
dorment = 0
done = False
